# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
PATH = "/home/paperspace/.kaggle/datasets/kmader/rsna-bone-age/"

# %%
ls {PATH}
# Out:
# boneage-test-dataset/     boneage-training-dataset/
# boneage-test-dataset.csv  boneage-training-dataset.csv
# boneage-test-dataset.zip  boneage-training-dataset.zip

# %%
from fastai.plots import *

# %%
def get_1st(path): return glob(f'{path}/*.*')[0]

# %%
list_paths = [get_1st(f"{PATH}boneage-training-dataset"), get_1st(f"{PATH}boneage-test-dataset")]
plots_from_files(list_paths, titles=["training", "test"], maintitle="Data examples")

# %% [markdown]
# Files in Training set:

# %%
# !find {PATH + "boneage-training-dataset"} -type f | wc -l
# Out:
# 12611

# %%
files = os.listdir(f'{PATH}boneage-training-dataset')[:5]
files
# Out:
# ['14412.png', '7908.png', '15496.png', '4165.png', '13696.png']

# %% [markdown]
# Files in Test set:

# %%
# !find {PATH + "boneage-test-dataset"} -type f | wc -l
# Out:
# 200

# %%
files = os.listdir(f'{PATH}boneage-test-dataset')[:5]
files
# Out:
# ['4409.png', '4459.png', '4382.png', '4515.png', '4362.png']

# %%
label_csv = PATH + "boneage-training-dataset.csv"
labels = pd.read_csv(label_csv)
len(labels)
# Out:
# 12611

# %%
labels.head()
# Out:
#      id  boneage   male
# 0  1377      180  False
# 1  1378       12  False
# 2  1379       94  False
# 3  1380      120   True
# 4  1381       82  False
